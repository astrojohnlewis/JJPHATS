# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy
# %matplotlib inline

# %%
import astropy.io.fits as fits

# %%
hdu=fits.open('dss_search.fits')

# %%
image=hdu[0].data

# %%
plt.imshow(image)
plt.show()

# %%
a=np.gradient(image)

# %%
plt.imshow(a[0])
plt.show()

# %%
plt.imshow(a[1])
plt.show()

# %%
plt.imshow(a[1],vmin=-1, vmax=1)
